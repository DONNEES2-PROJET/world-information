# %%
import pandas as pd

# %%
education_data = pd.read_csv("education-data.csv")

# %%
health_data = pd.read_csv("health-data.csv")
economics_data = pd.read_csv("economics-data.csv")

# %%
health_data["Physicians per thousand"] = education_data["Physicians per thousand"]

# %%
health_data.head()
# Out:
#    Unnamed: 0      Country  Life expectancy  Maternal mortality ratio  \
# 0           0  Afghanistan             64.5                     638.0
# 1           1      Albania             78.5                      15.0
# 2           2      Algeria             76.7                     112.0
# 3           3      Andorra              NaN                       NaN
# 4           4       Angola             60.8                     241.0
#
#   Out of pocket health expenditure  Infant mortality Minimum wage  \
# 0                           78.40%              47.9       $0.43
# 1                           56.90%               7.8       $1.12
# 2                           28.10%              20.1       $0.95
# 3                           36.40%               2.7       $6.63
# 4                           33.40%              51.6       $0.71
#
#    Physicians per thousand
# 0                     0.28
# 1                     1.20
# 2                     1.72
# 3                     3.33
# ...

# %%
education_data.head()
# Out:
#    Unnamed: 0      Country Gross primary education enrollment (%)  \
# 0           0  Afghanistan                                104.00%
# 1           1      Albania                                107.00%
# 2           2      Algeria                                109.90%
# 3           3      Andorra                                106.40%
# 4           4       Angola                                113.50%
#
#   Gross tertiary education enrollment (%)  Physicians per thousand
# 0                                   9.70%                     0.28
# 1                                  55.00%                     1.20
# 2                                  51.40%                     1.72
# 3                                     NaN                     3.33
# 4                                   9.30%                     0.21

# %%
education_data = education_data.drop(columns = "Physicians per thousand")

# %%
education_data.head()
# Out:
#    Unnamed: 0      Country Gross primary education enrollment (%)  \
# 0           0  Afghanistan                                104.00%
# 1           1      Albania                                107.00%
# 2           2      Algeria                                109.90%
# 3           3      Andorra                                106.40%
# 4           4       Angola                                113.50%
#
#   Gross tertiary education enrollment (%)
# 0                                   9.70%
# 1                                  55.00%
# 2                                  51.40%
# 3                                     NaN
# 4                                   9.30%

# %%
health_data.head()
# Out:
#    Unnamed: 0      Country  Life expectancy  Maternal mortality ratio  \
# 0           0  Afghanistan             64.5                     638.0
# 1           1      Albania             78.5                      15.0
# 2           2      Algeria             76.7                     112.0
# 3           3      Andorra              NaN                       NaN
# 4           4       Angola             60.8                     241.0
#
#   Out of pocket health expenditure  Infant mortality
# 0                           78.40%              47.9
# 1                           56.90%               7.8
# 2                           28.10%              20.1
# 3                           36.40%               2.7
# 4                           33.40%              51.6

# %%
economics_data["Minimum wage"] = health_data["Minimum wage"]

# %%
economics_data.head()
# Out:
#    Unnamed: 0      Country Tax revenue (%) Total tax rate                GDP  \
# 0           0  Afghanistan           9.30%         71.40%   $19,101,353,833
# 1           1      Albania          18.60%         36.60%   $15,278,077,447
# 2           2      Algeria          37.20%         66.10%  $169,988,236,398
# 3           3      Andorra             NaN            NaN    $3,154,057,987
# 4           4       Angola           9.20%         49.10%   $94,635,415,870
#
#   Gasoline Price Minimum wage     CPI CPI Change (%)
# 0         $0.70        $0.43   149.90          2.30%
# 1         $1.36        $1.12   119.05          1.40%
# 2         $0.28        $0.95   151.36          2.00%
# 3         $1.51        $6.63      NaN            NaN
# 4         $0.97        $0.71   261.73         17.10%

# %%
health_data = health_data.drop(columns = "Minimum wage")
